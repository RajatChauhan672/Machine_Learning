# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\rajat\Desktop\Data_sets\HousingData.csv")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data['CRIM'].fillna(data['CRIM'].mean(),inplace=True)
data['ZN'].fillna(data['ZN'].mean(),inplace=True)
data['AGE'].fillna(data['AGE'].mean(),inplace=True)
data['LSTAT'].fillna(data['LSTAT'].mean(),inplace=True)
data['INDUS'].fillna(data['INDUS'].mean(),inplace=True)
data['CHAS'].fillna(data['CHAS'].mean(),inplace=True)

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.182930  0.391161 -0.052223  0.410377 -0.215434  0.344934
# ZN      -0.182930  1.000000 -0.513336 -0.036147 -0.502287  0.316550 -0.541274
# INDUS    0.391161 -0.513336  1.000000  0.058035  0.740965 -0.381457  0.614592
# CHAS    -0.052223 -0.036147  0.058035  1.000000  0.073286  0.102284  0.075206
# NOX      0.410377 -0.502287  0.740965  0.073286  1.000000 -0.302188  0.711461
# RM      -0.215434  0.316550 -0.381457  0.102284 -0.302188  1.000000 -0.241351
# AGE      0.344934 -0.541274  0.614592  0.075206  0.711461 -0.241351  1.000000
# DIS     -0.366523  0.638388 -0.699639 -0.091680 -0.769230  0.205246 -0.724353
# RAD      0.608886 -0.306316  0.593176  0.001425  0.611441 -0.209847  0.449989
# TAX      0.566528 -0.308334  0.716062 -0.031483  0.668023 -0.292048  0.500589
# PTRATIO  0.273384 -0.403085  0.384806 -0.109310  0.188933 -0.355501  0.262723
# B       -0.370163  0.167431 -0.354597  0.050055 -0.380051  0.128069 -0.265282
# LSTAT    0.434044 -0.407549  0.567354 -0.046166  0.572379 -0.602962  0.574893
# MEDV    -0.379695  0.365943 -0.478657  0.179882 -0.427321  0.695360 -0.380223
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.366523  0.608886  0.566528  0.273384 -0.370163  0.434044 -0.379695
# ZN       0.638388 -0.306316 -0.308334 -0.403085  0.167431 -0.407549  0.365943
# INDUS   -0.699639  0.593176  0.716062  0.384806 -0.354597  0.567354 -0.478657
# CHAS    -0.091680  0.001425 -0.031483 -0.109310  0.050055 -0.046166  0.179882
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.572379 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.602962  0.695360
# AGE     -0.724353  0.449989  0.500589  0.262723 -0.265282  0.574893 -0.380223
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.483429  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.468440 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.524545 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.373343 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.368886  0.333461
# LSTAT   -0.483429  0.468440  0.524545  0.373343 -0.368886  1.000000 -0.721975
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.721975  1.000000

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(data['CRIM'],data['MEDV'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(data["RM"],data['MEDV'])
plt.xlabel("LSTAT")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x="RM",y="MEDV",data=data)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x="CRIM",y="MEDV",data=data)
# Out:
# <Axes: xlabel='CRIM', ylabel='MEDV'>

# %%
sns.boxplot(data['CRIM'])
# Out:
# <Axes: >

# %%
#Independent Feature

X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
##Standardize the datasets
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
##using Ridge Regression
from sklearn.linear_model import Ridge
rid=Ridge(alpha=3.0)

# %%
rid.fit(x_train,y_train)
# Out:
# Ridge(alpha=3.0)

# %%
y_pred_1=rid.predict(x_test)

# %%
y_pred_1
# Out:
# array([28.8152279 , 36.94690493, 15.40982694, 25.57143706, 18.50665789,
#        22.93598194, 18.05023166, 14.51055858, 21.93818486, 20.85739529,
#        25.06930461, 18.84707996, -6.14015262, 21.91889577, 19.06050574,
#        25.30518063, 19.19254314,  5.95535426, 40.67073474, 17.18390947,
#        24.84349237, 30.20108421, 11.53344685, 22.79535625, 17.48239585,
#        15.02647254, 21.41180923, 14.53765757, 23.14145166, 19.62106534,
#        22.11426937, 25.26706435, 25.30371729, 17.33102337, 16.15329066,
#        17.40618858, 30.92345141, 20.42519651, 24.70977968, 22.84851882,
#        14.58926866, 31.57161057, 42.526872  , 18.09742167, 27.342216  ,
#        16.52078635, 14.05214697, 26.51033156, 19.66336842, 30.30828379,
#        21.11576899, 33.35655117, 16.08542743, 26.30678298, 39.43881384,
#        22.4463123 , 18.72775893, 32.81874142, 25.25468267, 13.27488014,
#        22.92957856, 30.96020802, 31.41740845, 16.82195677, 21.53466512,
#        17.1534814 , 19.94156163, 26.35571195, 31.15542578, 11.76491641,
#        20.95962302, 26.50703955, 11.00193746, 13.81192305, 23.96301603,
#         5.74831869, 21.48055573, 41.27969471, 18.13416604,  9.73904226,
#        21.50631039, 12.72410153, 21.98459917,  9.16141706, 22.7559242 ,
#        32.48355258, 19.09531937, 25.76985892, 28.83857858, 19.86429105,
#        25.95801697,  5.60741942, 19.76129968, 15.87527023, 11.9746909 ,
#        20.36405503, 23.57442297, -0.34582919, 13.64039436, 15.51753135,
#        22.62470228, 24.6434827 , 10.39740933, 19.79542353, 23.32417962,
#        12.49448113, 18.56521533, 26.00772092, 21.27508771, 24.869608  ,
#         7.96398857, 20.12873031, 22.23415528, 27.36206765, 31.91487056,
#        14.80341107, 34.663466  , 13.18190387, 21.36165513, 28.26270596,
#        15.49985041, 25.24326626,  3.59302553, 23.75060355, 26.2585561 ,
#        23.11980971, 25.50756465, 33.06348726, 21.86366257, 38.31656842,
#        14.23395921, 26.30719568, 17.71332926, 20.83307917, 10.67959676,
#        20.39404296, 22.6712293 , 31.8975151 , 31.73153855, 15.64777876,
#        17.12773898, 29.09595461, 25.00268325, 17.56980824,  6.63413433,
#        25.77649778, 23.98330469, 20.48524013, 13.71201566, 40.0980692 ,
#        16.40712847, 17.88424564])

# %%
plt.scatter(y_pred_1,y_test)

# %%
residuals=y_pred_1-y_test

# %%
sns.displot(residuals,kind="kde")

# %%
plt.scatter(y_pred_1,residuals)

# %%
from sklearn.metrics  import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred_1))
print(mean_absolute_error(y_test,y_pred_1))
print(np.sqrt(mean_squared_error(y_test,y_pred_1)))
# Out:
# 21.893249634678998
# 3.141170998686268
# 4.679022294740537

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_pred_1)
score
# Out:
# 0.7061825244565436

# %%
n=len(y_test)-1
k=len(data.columns)-1

# %%
adjusted_r2_score=1-((1-score)*(n-1)/(n-k-1))
adjusted_r2_score
# Out:
# 0.6783020340765076

# %%
# Lesso Regression
from sklearn.linear_model import Lasso
las=Lasso(alpha=1.0)

# %%
las.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred_2=las.predict(x_test)

# %%
y_pred
# Out:
# array([28.94684244, 37.080947  , 15.16334344, 25.59977001, 18.52050399,
#        22.92953198, 17.99840423, 14.43800382, 22.06639946, 20.81944231,
#        25.11881906, 18.72123522, -6.3071011 , 21.86734043, 19.02489041,
#        25.40599155, 19.37239698,  5.95086419, 40.85794132, 17.18432226,
#        24.93251127, 30.36869589, 11.39935905, 22.76748541, 17.50857422,
#        15.11943012, 21.39728476, 14.47830797, 23.13536511, 19.56542429,
#        22.18119889, 25.26140438, 25.38274556, 17.33845553, 16.24266113,
#        17.25502918, 30.91188566, 20.39390975, 24.67921133, 22.85756708,
#        14.52166278, 31.79401526, 42.81650058, 17.99338659, 27.3605525 ,
#        16.56320925, 13.95314318, 26.53462251, 19.75194991, 30.2586963 ,
#        21.02578   , 33.48015966, 15.97922002, 26.27389748, 39.58817583,
#        22.50675409, 18.73574376, 33.02789505, 25.25340181, 13.16505164,
#        22.85496664, 31.01835795, 31.53871931, 16.756762  , 21.22003054,
#        17.10830699, 19.99132099, 26.38841982, 31.29685552, 11.7231931 ,
#        20.97258967, 26.63335287, 10.95888213, 13.4158528 , 23.97236272,
#         5.66817291, 21.45418183, 41.56712305, 18.17594507,  9.48043905,
#        21.41371834, 12.83886454, 21.86984499,  9.17605135, 22.77784869,
#        32.52178098, 19.08870649, 25.76101077, 29.03718152, 19.79942549,
#        25.99768914,  5.55973693, 19.67592421, 15.58843642, 12.05864065,
#        20.27908381, 23.71715385, -0.33118013, 13.574537  , 15.58002707,
#        22.63744043, 24.63223041, 10.44203817, 19.7020956 , 23.19945908,
#        12.54800472, 18.49880298, 25.97268923, 21.20986934, 24.74534596,
#         7.87558719, 20.25419972, 22.14202929, 27.49138377, 32.02443374,
#        14.76313946, 34.77670429, 13.04840788, 21.34756531, 28.27990076,
#        15.36800974, 25.1865523 ,  3.35128356, 23.72015504, 26.26550372,
#        23.10384338, 25.43047681, 33.18312767, 21.64835442, 38.47259389,
#        14.41283553, 26.16157834, 17.60366271, 20.79190337, 10.45939827,
#        20.49798709, 22.67008757, 31.99471793, 31.79670093, 15.52452541,
#        17.02050129, 29.09484276, 25.06877192, 17.53901345,  6.54114984,
#        25.94712745, 23.79112755, 20.48659363, 13.59421774, 40.22597747,
#        16.39307918, 17.86909777])

# %%
Residuals=y_pred_2-y_test

# %%
plt.scatter(y_pred_2,y_test)

# %%
plt.scatter(y_pred_2,residuals)

# %%
sns.displot(residuals,kind="kde")

# %%
from sklearn.metrics  import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred_2))
print(mean_absolute_error(y_test,y_pred_2))
print(np.sqrt(mean_squared_error(y_test,y_pred_2)))
# Out:
# 26.449679376990815
# 3.658843183692169
# 5.1429251770748925

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_pred_2)
score
# Out:
# 0.6450331424910367

# %%
n=len(y_test)-1
k=len(data.columns)-1
adjusted_r2_score=1-((1-score)*(n-1)/(n-k-1))
adjusted_r2_score
# Out:
# 0.611350156012084

# %%
## Elasticnet Regression
from sklearn.linear_model import ElasticNet
elastic=ElasticNet()

# %%
elastic.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred_3=lr.predict(x_test)

# %%
print(elastic.coef_)
# Out:
# [-0.43013305  0.         -0.23091694  0.66075211 -0.19128547  2.45132128
#  -0.08252991 -0.         -0.         -0.31457048 -1.25488966  0.53197506
#  -2.36108338]

# %%
print(elastic.intercept_)
# Out:
# 23.01581920903955

# %%
plt.scatter(y_pred_3,y_test)
plt.xlabel("Predicted Data")
plt.ylabel("Actual or test data")
# Out:
# Text(0, 0.5, 'Actual or test data')

# %%
## Residuals
residuals=y_pred-y_test

# %%
sns.displot(residuals,kind="kde")

# %%
plt.scatter(y_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(y_test,y_pred_3))
print(mean_absolute_error(y_test,y_pred_3))
print(np.sqrt(mean_squared_error(y_test,y_pred_3)))
# Out:
# 21.818457953526046
# 3.141052567108469
# 4.6710232233982785

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.7071862632031756

# %%
n=len(y_test)
k=len(data.columns)-1

# %%
adjusted_r2_score=1-((1-score)*(n-1)/(n-k-1))

# %%
adjusted_r2_score
# Out:
# 0.6796023604614457
